# %%
import pandas as pd
import numpy as np

# %%
data2 = pd.read_csv("data.csv")
data = data2.to_numpy()

# %%
data
# Out:
# array([[3, 5],
#        [3, 4],
#        [5, 6],
#        [2, 6],
#        [4, 5],
#        [6, 8],
#        [6, 2],
#        [6, 3],
#        [5, 6],
#        [6, 7],
#        [7, 2],
#        [8, 5],
#        [9, 1],
#        [8, 2],
#        [9, 6],
#        [9, 1],
#        [8, 3]])

# %%
from sklearn.metrics import euclidean_distances

# %%
euclidean_distances(data)
# Out:
# array([[0.        , 1.        , 2.23606798, 1.41421356, 1.        ,
#         4.24264069, 4.24264069, 3.60555128, 2.23606798, 3.60555128,
#         5.        , 5.        , 7.21110255, 5.83095189, 6.08276253,
#         7.21110255, 5.38516481],
#        [1.        , 0.        , 2.82842712, 2.23606798, 1.41421356,
#         5.        , 3.60555128, 3.16227766, 2.82842712, 4.24264069,
#         4.47213595, 5.09901951, 6.70820393, 5.38516481, 6.32455532,
#         6.70820393, 5.09901951],
#        [2.23606798, 2.82842712, 0.        , 3.        , 1.41421356,
#         2.23606798, 4.12310563, 3.16227766, 0.        , 1.41421356,
#         4.47213595, 3.16227766, 6.40312424, 5.        , 4.        ,
#         6.40312424, 4.24264069],
#        [1.41421356, 2.23606798, 3.        , 0.        , 2.23606798,
#         4.47213595, 5.65685425, 5.        , 3.        , 4.12310563,
#         6.40312424, 6.08276253, 8.60232527, 7.21110255, 7.        ,
#         8.60232527, 6.70820393],
#        [1.        , 1.41421356, 1.41421356, 2.23606798, 0.        ,
#         3.60555128, 3.60555128, 2.82842712, 1.41421356, 2.82842712,
#         4.24264069, 4.        , 6.40312424, 5.        , 5.09901951,
#         6.40312424, 4.47213595],
#        [4.24264069, 5.        , 2.23606798, 4.47213595, 3.60555128,
#         0.        , 6.        , 5.        , 2.23606798, 1.        ,
#         6.08276253, 3.60555128, 7.61577311, 6.32455532, 3.60555128,
#         7.61577311, 5.38516481],
#        [4.24264069, 3.60555128, 4.12310563, 5.65685425, 3.60555128,
#         6.        , 0.        , 1.        , 4.12310563, 5.        ,
#         1.        , 3.60555128, 3.16227766, 2.        , 5.        ,
#         3.16227766, 2.23606798],
#        [3.60555128, 3.16227766, 3.16227766, 5.        , 2.82842712,
#         5.        , 1.        , 0.        , 3.16227766, 4.        ,
#         1.41421356, 2.82842712, 3.60555128, 2.23606798, 4.24264069,
#         3.60555128, 2.        ],
#        [2.23606798, 2.82842712, 0.        , 3.        , 1.41421356,
#         2.23606798, 4.12310563, 3.16227766, 0.        , 1.41421356,
#         4.47213595, 3.16227766, 6.40312424, 5.        , 4.        ,
#         6.40312424, 4.24264069],
#        [3.60555128, 4.24264069, 1.41421356, 4.12310563, 2.82842712,
#         1.        , 5.        , 4.        , 1.41421356, 0.        ,
#         5.09901951, 2.82842712, 6.70820393, 5.38516481, 3.16227766,
#         6.70820393, 4.47213595],
#        [5.        , 4.47213595, 4.47213595, 6.40312424, 4.24264069,
#         6.08276253, 1.        , 1.41421356, 4.47213595, 5.09901951,
#         0.        , 3.16227766, 2.23606798, 1.        , 4.47213595,
#         2.23606798, 1.41421356],
#        [5.        , 5.09901951, 3.16227766, 6.08276253, 4.        ,
#         3.60555128, 3.60555128, 2.82842712, 3.16227766, 2.82842712,
#         3.16227766, 0.        , 4.12310563, 3.        , 1.41421356,
#         4.12310563, 2.        ],
#        [7.21110255, 6.70820393, 6.40312424, 8.60232527, 6.40312424,
#         7.61577311, 3.16227766, 3.60555128, 6.40312424, 6.70820393,
#         2.23606798, 4.12310563, 0.        , 1.41421356, 5.        ,
#         0.        , 2.23606798],
#        [5.83095189, 5.38516481, 5.        , 7.21110255, 5.        ,
#         6.32455532, 2.        , 2.23606798, 5.        , 5.38516481,
#         1.        , 3.        , 1.41421356, 0.        , 4.12310563,
#         1.41421356, 1.        ],
#        [6.08276253, 6.32455532, 4.        , 7.        , 5.09901951,
#         3.60555128, 5.        , 4.24264069, 4.        , 3.16227766,
#         4.47213595, 1.41421356, 5.        , 4.12310563, 0.        ,
#         5.        , 3.16227766],
#        [7.21110255, 6.70820393, 6.40312424, 8.60232527, 6.40312424,
#         7.61577311, 3.16227766, 3.60555128, 6.40312424, 6.70820393,
#         2.23606798, 4.12310563, 0.        , 1.41421356, 5.        ,
#         0.        , 2.23606798],
#        [5.38516481, 5.09901951, 4.24264069, 6.70820393, 4.47213595,
#         5.38516481, 2.23606798, 2.        , 4.24264069, 4.47213595,
#         1.41421356, 2.        , 2.23606798, 1.        , 3.16227766,
#         2.23606798, 0.        ]])

# %%
import math

# %%
def e_dist(x,y):
    return ((x[0]-y[0]) ** 2 + (x[1]-y[1]) ** 2)**(1/2)

# %%
def print_dist(data, centroid1, centroid2):
    i=1
    for x in data:
        print(i, e_dist(x, centroid1), " \t", e_dist(x, centroid2))
        i+=1

# %%
i=1
for x in data:
    print(i, e_dist(x, (3,5)), " \t", e_dist(x, (8,2)))
    i+=1
# Out:
# 1 0.0  	 5.830951894845301
# 2 1.0  	 5.385164807134504
# 3 2.23606797749979  	 5.0
# 4 1.4142135623730951  	 7.211102550927978
# 5 1.0  	 5.0
# 6 4.242640687119285  	 6.324555320336759
# 7 4.242640687119285  	 2.0
# 8 3.605551275463989  	 2.23606797749979
# 9 2.23606797749979  	 5.0
# 10 3.605551275463989  	 5.385164807134504
# 11 5.0  	 1.0
# 12 5.0  	 3.0
# 13 7.211102550927978  	 1.4142135623730951
# 14 5.830951894845301  	 0.0
# 15 6.082762530298219  	 4.123105625617661
# 16 7.211102550927978  	 1.4142135623730951
# 17 5.385164807134504  	 1.0

# %%
c1=[
    [3,5],
    [3,4],
    [5,6],
    [2,6],
    [4,5],
    [6,8],
    [5,6],
    [6,7]
]

# %%
c2=[
    [6,2],
    [6,3],
    [7,2],
    [8,5],
    [9,1],
    [8,2],
    [9,6],
    [9,1],
    [8,3]
]

# %%
len(c1)
# Out:
# 8

# %%
len(c2)
# Out:
# 9

# %%
centroid1 = [4.25,5.875]
centroid2 = [7.78, 2.78]

# %%
print_dist(c1, centroid1, centroid2)
# Out:
# 1 1.5258194519667128  	 5.2703700059862975
# 2 2.2534695471649933  	 4.93323423323888
# 3 0.7603453162872774  	 4.254033380216945
# 4 2.2534695471649933  	 6.616403857081277
# 5 0.9100137361600648  	 4.38369706982588
# 6 2.752839443193155  	 5.51514279053589
# 7 0.7603453162872774  	 4.254033380216945
# 8 2.080414622136655  	 4.580043667914096

# %%
print_dist(c2, centroid1, centroid2)
# Out:
# 1 4.251837837923738  	 1.9433990840792328
# 2 3.365728004459065  	 1.793543977715629
# 3 4.751644452187053  	 1.1030865786510142
# 4 3.8507304501873407  	 2.230874268084152
# 5 6.806476695030991  	 2.1579620015190257
# 6 5.392413652530748  	 0.8104319835741921
# 7 4.751644452187053  	 3.4433704418781317
# 8 6.806476695030991  	 2.1579620015190257
# 9 4.72526454285895  	 0.31112698372208086

# %%
## Import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
## Load Data
dfa = pd.read_csv("data.csv")
sc_dfa = StandardScaler()
dfa_std = sc_dfa.fit_transform(dfa.astype(float))

# %%
## Clustering with KMeans
kmeans2 = KMeans(n_clusters=2, random_state=42).fit(dfa_std)
kmeans3 = KMeans(n_clusters=3, random_state=42).fit(dfa_std)
kmeans4 = KMeans(n_clusters=4, random_state=42).fit(dfa_std)


labels2 = kmeans2.labels_
labels3 = kmeans3.labels_
labels4 = kmeans4.labels_

# %%
new_dfa = pd.DataFrame(data = dfa_std, columns = ['spending index','income index'])
new_dfa['label_kmeans'] = labels2
fig, ax = plt.subplots(figsize=(10,7))
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 0], new_dfa["spending index"][new_dfa["label_kmeans"] == 0], 
            color = "blue", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 1], new_dfa["spending index"][new_dfa["label_kmeans"] == 1], 
            color = "red", s=100, edgecolor='green',linestyle='--')
# plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 2], new_dfa["spending index"][new_dfa["label_kmeans"] == 2], 
#             color = "green", s=100, edgecolor='green',linestyle='--')
centers = kmeans2.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
ax.set_xlabel('income index')
ax.set_ylabel('spending index')
plt.show()

# %%
new_dfa = pd.DataFrame(data = dfa_std, columns = ['spending index','income index'])
new_dfa['label_kmeans'] = labels3
fig, ax = plt.subplots(figsize=(10,7))
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 0], new_dfa["spending index"][new_dfa["label_kmeans"] == 0], 
            color = "blue", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 1], new_dfa["spending index"][new_dfa["label_kmeans"] == 1], 
            color = "red", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 2], new_dfa["spending index"][new_dfa["label_kmeans"] == 2], 
            color = "green", s=100, edgecolor='green',linestyle='--')
centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
ax.set_xlabel('income index')
ax.set_ylabel('spending index')
plt.show()

# %%
new_dfa = pd.DataFrame(data = dfa_std, columns = ['spending index','income index'])
new_dfa['label_kmeans'] = labels4
fig, ax = plt.subplots(figsize=(10,7))
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 0], new_dfa["spending index"][new_dfa["label_kmeans"] == 0], 
            color = "blue", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 1], new_dfa["spending index"][new_dfa["label_kmeans"] == 1], 
            color = "red", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 2], new_dfa["spending index"][new_dfa["label_kmeans"] == 2], 
            color = "green", s=100, edgecolor='green',linestyle='--')
plt.scatter(new_dfa["income index"][new_dfa["label_kmeans"] == 3], new_dfa["spending index"][new_dfa["label_kmeans"] == 3], 
            color = "yellow", s=100, edgecolor='green',linestyle='--')
centers = kmeans4.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
ax.set_xlabel('income index')
ax.set_ylabel('spending index')
plt.show()
